# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
import cufflinks as cf

# %%
init_notebook_mode(connected=True) #conecta com o notebook, pra poder rodar as coisas nesse ambiente
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#df = pd.DataFrame(data=np.random.randn(100,4), columns='A B C D'.split()).T INVERTE AS LINHAS COM AS COLUNAS
df = pd.DataFrame(data=np.random.randn(100,4), columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.739573  0.547808  0.819528 -0.061464
# 1 -0.659836 -0.272854  1.355958  0.085554
# 2  1.109850  0.948424 -1.035266 -1.435418
# 3 -1.201184 -0.541880 -0.638126  0.590196
# 4 -0.427651 -0.064468  0.590252  0.657262

# %%
df2 = pd.DataFrame(data={'Categoria':'A B C'.split(), 'Valores':[32, 43, 50]})

# %%
df2
# Out:
#   Categoria  Valores
# 0         A       32
# 1         B       43
# 2         C       50

# %% [markdown]
# ## Utilizando o próprio Pandas para plotar

# %%
#df.plot.scatter(x='A', y='B', s=df['C']*20)
df.plot(x='A', y='B', kind='scatter')

# %% [markdown]
# ## Utilizando o Plotly

# %%
df.iplot(x='A', y='B', kind='scatter', mode='markers')

# %%
df2.iplot(kind='bar', x='Categoria', y='Valores')

# %%
df.iplot(kind='bar')

# %%
df.iplot(kind='line')

# %%
df.count().iplot(kind='bar')

# %%
df.iplot(kind='box')

# %% [markdown]
# ## **Criação de interfaces 3D**

# %%
df3 = pd.DataFrame(data={'x': [1, 2, 3, 4, 5], 'y': [10, 20, 30, 40, 50], 'z': [5, 4, 3, 2, 1]}, index='line1 line2 line3 line4 line5'.split())

# %%
df3
# Out:
#        x   y  z
# line1  1  10  5
# line2  2  20  4
# line3  3  30  3
# line4  4  40  2
# line5  5  50  1

# %%
df3.iplot(kind='surface', colorscale='rdylbu')

# %% [markdown]
# ### Séries temporais, variáveis em função do tempo; muito utilizado no mercado financeiro.

# %%
df[['A','B']].iplot(kind='spread')

# %%
df['A'].iplot(kind='hist',bins=50)

# %%
df.iplot(kind='bubble', x='B', y='C', size='A')

# %%
#supondo q sao todos valores numericos
df.
