# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.style.available
# Out:
# ['_classic_test',
#  'seaborn',
#  'Solarize_Light2',
#  'seaborn-pastel',
#  'classic',
#  'fivethirtyeight',
#  'seaborn-colorblind',
#  'ggplot',
#  'seaborn-white',
#  'grayscale',
#  'fast',
#  'seaborn-darkgrid',
#  'seaborn-talk',
#  'bmh',
#  'seaborn-poster',
#  'seaborn-dark-palette',
#  'seaborn-whitegrid',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'dark_background',
#  'seaborn-dark',
#  'seaborn-muted',
#  'seaborn-bright',
#  'tableau-colorblind10',
#  'seaborn-ticks',
#  'seaborn-deep']

# %%
#estilos
plt.style.available #ve os estilos que tem disponiveis
plt.style.use('seaborn')
plt.style.use('bmh')
plt.style.use('ggplot')
plt.style.use('fivethirtyeight')

# %%
df1 = pd.read_csv('df1')

# %%
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2000-01-01 to 2002-09-26
# Data columns (total 4 columns):
# A    1000 non-null float64
# B    1000 non-null float64
# C    1000 non-null float64
# D    1000 non-null float64
# dtypes: float64(4)
# memory usage: 39.1+ KB

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
# a    10 non-null float64
# b    10 non-null float64
# c    10 non-null float64
# d    10 non-null float64
# dtypes: float64(4)
# memory usage: 400.0 bytes

# %%
#df1['A'].plot.hist() vem mais detalhado
df1['A'].hist(rwidth=0.9) #histograma

# %%
df2.plot.area(figsize=(12,8), alpha=0.6) #alpha e a opacidade

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True) #stacked agrega as barras

# %%
df1['A'].plot.hist() #

# %%
df1.index.values #pegar os valores do index
index = df1.index.tolist() #outra forma

# %%
df1.plot.line(y='B',figsize = (12,5), lw=0.8)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='inferno') #grafico matricial é cmap, categorico e pallete

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*20)

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.rand(1000,2), columns=['A','B'])

# %%
df
# Out:
#             A         B
# 0    0.004013  0.052909
# 1    0.454661  0.296450
# 2    0.881767  0.737740
# 3    0.268043  0.594496
# 4    0.589838  0.360232
# 5    0.699538  0.906074
# 6    0.926678  0.250084
# 7    0.703252  0.652603
# 8    0.702695  0.376246
# 9    0.735986  0.601418
# 10   0.447925  0.828264
# 11   0.973668  0.424611
# 12   0.073192  0.841036
# 13   0.663045  0.718272
# 14   0.432134  0.665884
# 15   0.948890  0.663624
# 16   0.763255  0.496760
# 17   0.571988  0.262558
# 18   0.607444  0.798446
# 19   0.667020  0.261271
# 20   0.437371  0.416567
# 21   0.575914  0.815733
# 22   0.397126  0.655475
# 23   0.147700  0.730208
# 24   0.437211  0.658549
# 25   0.436027  0.558941
# 26   0.585873  0.514343
# 27   0.325393  0.880745
# 28   0.971553  0.419847
# 29   0.412794  0.108705
# ..        ...       ...
# 970  0.912856  0.002089
# 971  0.103047  0.056124
# 972  0.289042  0.489684
# 973  0.103694  0.845485
# 974  0.260822  0.158652
# 975  0.840428  0.906175
# ...

# %%
df.plot.hexbin(x='A', y='B', gridsize=20, cmap='Oranges')

# %%
df2.plot.kde()
