# %%
import tabula

# %%
df = tabula.read_pdf('data.pdf',multiple_tables=True)

# %%
df
# Out:
# [                      0        1                                         2  \
#  0                   NaN      NaN                                       NaN
#  1             Estudante  Unidade                        Título do Trabalho
#  2                   NaN      NaN                                       NaN
#  3                   NaN      NaN           CARACTERÍSTICAS FÍSICAS DO SOLO
#  4     ABEL PEREIRA LIMA      NaN             DESEMPENHO AGRONÔMICO DA SOJA
#  5                   NaN     CPCS                                       NaN
#  6                SOARES      NaN              INFLUENCIADAS POR PLANTAS DE
#  7                   NaN      NaN            COBERTURAS E DOSES DE CALCÁRIO
#  8     ABEL PEREIRA LIMA      NaN       DESEMPENHO AGRONÔMICO DE CULTIVARES
#  9                   NaN     CPCS                                       NaN
#  10               SOARES      NaN                    DE SOJA COM E SEM BORO
# ...
