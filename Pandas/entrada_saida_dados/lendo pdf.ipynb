# %%
import camelot
import pandas as pd
import json
from collections import defaultdict
from functools import reduce

# %%
all_data = defaultdict(list)

# %%
tables = camelot.read_pdf('data.pdf', pages='1-54', flavor='lattice',strip_text='\n')

# %%
tables
# Out:
# <TableList n=54>

# %%
tables[0].df.to_dict()

# %%
data_frames = []
for i in range(len(tables)):
    data_frames.append(tables[i].df)

# %%
data_frames

# %%
df_merged = reduce(lambda left,right: pd.merge(left,right,on=[0,1,2,3,4],
                                            how='outer'), data_frames)

# %%
df_merged
# Out:
#                                                 0        1  \
# 0                                       Estudante  Unidade
# 1                        ABEL PEREIRA LIMA SOARES     CPCS
# 2                        ABEL PEREIRA LIMA SOARES     CPCS
# 3                  ADALGISA APARECIDA DE OLIVEIRA    FAALC
# 4                      ADÃO CAETANO DE DEUS FILHO     CPAQ
# 5                   ADAUTO FERREIRA DE SOUZA NETO    FAENG
# 6                      ADELSON DOURADO CAVALCANTE     CPCX
# 7                  ADILSON CORREA DA SILVA JUNIOR     CPAN
# 8                            ADOLPHO NILSON PRADO     CPNV
# 9                 ÁDRIA SAVIANO FABRICIO DA SILVA    FADIR
# 10           ADRIANA FERREIRA MODESTO DE OLIVEIRA    INISA
# 11                   ADRIANA MORAES DO NASCIMENTO     CPNV
# 12                            ADRIANO NOBRE ARCOS    INBIO
# 13            ADRIELLY AUXILIADORA FREIRE MIRANDA     CPAN
# 14                      ADRIELY RIBEIRO GUIMARÃES    INISA
# ...

# %%
df1 = tables[0].df
df2 = tables[1].df

# %%
tables[53].df

# %%
# pd.concat([df1,df2])
pd.merge(tables[0].df,tables[1].df,how='outer',on=[0,1,2,3,4])
# pd.merge(tables[2].df,tables[3].df,how='outer',on=[0,1,2,3,4])
# Out:
#                                           0        1  \
# 0                                 Estudante  Unidade
# 1                  ABEL PEREIRA LIMA SOARES     CPCS
# 2                  ABEL PEREIRA LIMA SOARES     CPCS
# 3            ADALGISA APARECIDA DE OLIVEIRA    FAALC
# 4                ADÃO CAETANO DE DEUS FILHO     CPAQ
# 5             ADAUTO FERREIRA DE SOUZA NETO    FAENG
# 6                ADELSON DOURADO CAVALCANTE     CPCX
# 7            ADILSON CORREA DA SILVA JUNIOR     CPAN
# 8                      ADOLPHO NILSON PRADO     CPNV
# 9           ÁDRIA SAVIANO FABRICIO DA SILVA    FADIR
# 10     ADRIANA FERREIRA MODESTO DE OLIVEIRA    INISA
# 11             ADRIANA MORAES DO NASCIMENTO     CPNV
# 12                      ADRIANO NOBRE ARCOS    INBIO
# 13      ADRIELLY AUXILIADORA FREIRE MIRANDA     CPAN
# 14                ADRIELY RIBEIRO GUIMARÃES    INISA
# 15          AGHATA THAYARA DE BRITO RIBEIRO    INQUI
# 16       AGNER FERREIRA DOS SANTOS MOSCARDI     CPAQ
# ...

# %%
for row in tables[0].cells:
    for cell in row:
        print(cell.x1, cell.y1, cell.x2, cell.y2)

# %%
df[2].loc[1]
# Out:
# 'CARACTERÍSTICAS FÍSICAS DO SOLO DESEMPENHO AGRONÔMICO DA SOJA INFLUENCIADAS POR PLANTAS DE COBERTURAS E DOSES DE CALCÁRIO'

# %%
with open('data.json','w', encoding='utf-8') as file:
    file.write(json.dumps(df.to_dict(), ensure_ascii=False, indent=4))
