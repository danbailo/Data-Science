# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(np.random.randn(5,4), index='A B C D E'.split(), columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
bol = df > 0

# %%
bol
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df[bol]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['W']>0] #printa o dataframe, porem, remove a linha onde o W é < 0
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['W']>0]['Y'] #retorna os valores da coluna Y, aos quais os valores da coluna W sao maiores q 0
# Out:
# A    0.907969
# B   -0.848077
# D   -0.933237
# E    2.605967
# Name: Y, dtype: float64

# %% [markdown]
# **Operador binário de dataframe**
#
# `& = and`
# `| = or`

# %%
df[(df['W']>0) & (df['Y']<0)]
# Out:
#           W         X         Y         Z
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index() #reseta o indice para um autoincrement e o indice anterior vira uma coluna
# Out:
#   index         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#   index         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
df['index']
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# Name: index, dtype: object

# %%
df['Estado'] = 'SP RS RJ MG ES'.split()

# %%
df
# Out:
#   index         W         X         Y         Z Estado
# 0     A  2.706850  0.628133  0.907969  0.503826     SP
# 1     B  0.651118 -0.319318 -0.848077  0.605965     RS
# 2     C -2.018168  0.740122  0.528813 -0.589001     RJ
# 3     D  0.188695 -0.758872 -0.933237  0.955057     MG
# 4     E  0.190794  1.978757  2.605967  0.683509     ES

# %%
df.set_index('Estado',inplace=True)

# %%
df
# Out:
#        index         W         X         Y         Z
# Estado
# SP         A  2.706850  0.628133  0.907969  0.503826
# RS         B  0.651118 -0.319318 -0.848077  0.605965
# RJ         C -2.018168  0.740122  0.528813 -0.589001
# MG         D  0.188695 -0.758872 -0.933237  0.955057
# ES         E  0.190794  1.978757  2.605967  0.683509

# %%
df.drop('index',axis=1,inplace=True)

# %%
df
# Out:
#                W         X         Y         Z
# Estado
# SP      2.706850  0.628133  0.907969  0.503826
# RS      0.651118 -0.319318 -0.848077  0.605965
# RJ     -2.018168  0.740122  0.528813 -0.589001
# MG      0.188695 -0.758872 -0.933237  0.955057
# ES      0.190794  1.978757  2.605967  0.683509
